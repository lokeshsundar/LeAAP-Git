# %% [markdown]
# My Jupyter Notebook on watson studio

# %% [markdown]
# Name

# %%
print("Name is Lokesh")

# %% [markdown]
# Interest: Datascience and Analytics

# %% [markdown]
# "Data is the New Oil"
# https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pexels.com%2Fsearch%2Fdata%2F&psig=AOvVaw092BYBXuD4lcibiU9BQSU_&ust=1669659030294000&source=images&cd=vfe&ved=0CAwQjRxqFwoTCNj61N76zvsCFQAAAAAdAAAAABAE
